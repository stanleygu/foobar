# %%
myString = '''
hello
world
goodbye
'''

# %%
listOfStrings = myString.splitlines()

phrase = 'wor'

newString = []
for s in listOfStrings:
    if (s.find(phrase) is -1):
        newString.append(s)
        
print '\n'.join(newString)
# Out:
# hello
# goodbye
