# %%
# !pip install simworker celery redis notebooktools
import tellurium as te
import numpy as np
import matplotlib.pyplot as plt
import notebooktools.notebooktools as nb
import time
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# Out:
# Requirement already satisfied (use --upgrade to upgrade): simworker in /home/user/.virtualenvs/localpy/lib/python2.7/site-packages
# Requirement already satisfied (use --upgrade to upgrade): celery in /home/user/.virtualenvs/localpy/lib/python2.7/site-packages
# Requirement already satisfied (use --upgrade to upgrade): redis in /home/user/.virtualenvs/localpy/lib/python2.7/site-packages
# Requirement already satisfied (use --upgrade to upgrade): notebooktools in /home/user/.virtualenvs/localpy/lib/python2.7/site-packages
# Cleaning up...

# %%
model = '''
  #Reactions:
  J0:    -> S1;  J0_v0
  J1: S1 ->   ;  J1_k3*S1
  J2: S1 -> S2; (J2_k1*S1)*(1 + J2_c*S2^J2_q)
  J3: S2 ->   ;  J3_k2*S2

  # Species initializations:
  S1 = 0
  S2 = 1

  # Variable initializations:
  J0_v0 = 8
  J1_k3 = 1
  J2_k1 = 1
  J2_c  = 1
  J2_q  = 3
  J3_k2 = 5
'''

rr = te.loadAntimonyModel(model)
print rr.model.getGlobalParameterValues()

TIME_START = 0
TIME_END = 5
TIME_STEPS = 80

data = rr.simulate(TIME_START, TIME_END, TIME_STEPS)
c = np.copy(data) # need to copy results or else it gets changed later
te.plotArray(data)
# Out:
# [ 8.  1.  1.  1.  3.  5.]
# <module 'matplotlib.pyplot' from '/usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc'>

# %%
def makeNoise(results, mean=0, std=1):
    import numpy as np
    dim = results.shape
    numSpecies = dim[1] - 1
    numPoints = dim[0]
    noise = np.hstack([np.array([np.random.normal(mean, std, numPoints)]).T for s in range(numSpecies)])
    return noise

noise = makeNoise(c, std=0.2)
noisyResults = np.hstack((np.array([c[:, 0]]).T, c[:, 1:] + noise))

def getSim(rr, params):
    rr.reset()
    rr.model.setGlobalParameterValues(params)
    return rr.simulate(TIME_START, TIME_END, TIME_STEPS)

def getFitness(obs):
    expected = noisyResults

    sumofsquares = 0
    for index, value in np.ndenumerate(obs):
            expectedValue = expected[index[0], index[1]]
            residual = (value - expectedValue)
            sumofsquares += residual ** 2

    return sumofsquares

# %%
MAX_GENS = 100
POPULATION = 100

# %%
import diffevolution
de = diffevolution.DiffEvolution(rr,
                   fitnessFcn=getFitness,
                   simFcn=getSim,
                   MAX_GENS=MAX_GENS,
                   POPULATION=POPULATION,
                   paramRangeDict={
                     'J0_v0': (8, 8),
                     'J1_k3': (1, 1),
                     'J2_k1': (1, 1),
                     #'J2_c': (1, 1),
                     #'J2_q': (3, 3),
                     #'J3_k2': (5, 5)
                   })
de.start()
de.plotFitnesses()
de.plotBest(observed=noisyResults)
# Out:
# Requirement already up-to-date: notebooktools in /home/user/.virtualenvs/localpy/lib/python2.7/site-packages
# Cleaning up...
# Finished after 48.9445550442 seconds
# with population of 100 and 100 generations
# Best fitness value of 6.23101343517
# Best parameters of [8.0, 1.0, 1.0, 1.0157626354686493, 2.9423423071978, 5.005206563775171]

# %%
sbml = rr.getSBML()
expected = noisyResults
def asyncSim(rr, params):
    import tasks
    
    return tasks.rrChain.delay([
        ['load', sbml],
        ['reset'],
        [['model', 'setGlobalParameterValues'], params],
        ['simulate', TIME_START, TIME_END, TIME_STEPS]
    ])

def getAsyncFitness(obs):
    sumofsquares = 0
    for index, value in np.ndenumerate(obs):
        expectedValue = expected[index[0], index[1]]
        residual = (value - expectedValue)
        sumofsquares += residual ** 2
    return sumofsquares

# %%
import diffevolution
deAsync = diffevolution.DiffEvolution(rr,
                   fitnessFcn=getAsyncFitness,
                   simFcn=asyncSim,
                   ASYNC=True,
                   MAX_GENS=MAX_GENS,
                   POPULATION=POPULATION,
                   paramRangeDict={
                     'J0_v0': (8, 8),
                     'J1_k3': (1, 1),
                     'J2_k1': (1, 1),
                   })
deAsync.start()
deAsync.plotFitnesses()
deAsync.plotBest(observed=noisyResults)
# Out:
# Finished after 86.4476652145 seconds
# with population of 100 and 100 generations
# Best fitness value of 6.14667762907
# Best parameters of [8.0, 1.0, 1.0, 1.030853398393186, 2.9597638011386813, 5.062288280286161]

# %%
import tasks

# %%
import time
start = time.time()
tasks.add.delay(2, 2).get()
end = time.time()
print '%s seconds' % str(end-start)
# Out:
# 0.50691485405 seconds

# %%
import time
start = time.time()
numTrials = 1
asyncQueue = []
for i in range(numTrials):
    asyncQueue.append(tasks.add.delay(2, 2))
for job in asyncQueue:
    print job.get()
end = time.time()
print '%s seconds' % str(end-start)
print '%s seconds per job' % str((end-start)/ numTrials)
# Out:
# 4
# 0.506783008575 seconds
# 0.506783008575 seconds per job

# %%
from celery import group
import time
start = time.time()
numTrials = 30
asyncQueue = []
for i in range(numTrials):
    asyncQueue.append(tasks.add.s(2, 2))

result = group(asyncQueue).apply_async()
print result.get()
end = time.time()
print '%s seconds' % str(end-start)
print '%s seconds per job' % str((end-start)/ numTrials)
# Out:
# [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]
# 1.10001087189 seconds
# 0.0366670290629 seconds per job

# %%
import time
start = time.time()
numSims = 100
asyncQueue = []
for i in range(numSims):
    asyncQueue.append(tasks.rrChain.delay([['load', sbml], ['reset'], ['simulate', 0, 10000, 100]]))
for job in asyncQueue:
    job.get()
end = time.time()
print '%s seconds' % str(end-start)
print '%s seconds/sim' % str((end-start)/numSims)

# %%
from celery import group
import time
start = time.time()
#tasks.add.delay(2, 2).get()
asyncQueue = []
numSims = 100
for i in range(numSims):
    asyncQueue.append(tasks.rrChain.s([['load', sbml], ['reset'], ['simulate', 0, 10000, 100]]))
result = group(asyncQueue).apply_async()
result.get()
end = time.time()
print '%s seconds' % str(end-start)
print '%s seconds/sim' % str((end-start)/numSims)

# %%
import time
start = time.time()
numSims = 100
for i in range(numSims):
    #rr.load(sbml)
    rr.reset()
    rr.simulate(0, 10000, 100)
end = time.time()
print '%s seconds' % str(end-start)
print '%s seconds/sim' % str((end-start)/numSims)
# Out:
# 6.07111406326 seconds
# 0.607111406326 seconds/sim
